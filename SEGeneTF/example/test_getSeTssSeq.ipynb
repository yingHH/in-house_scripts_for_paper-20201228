# %%
from SEGeneTF.readFiles import read_se, read_annotation, read_chip_sigal_regions
from SEGeneTF.getSeTssSeq import get_SE_constitute_regions, get_tss_constitute_regions
from SEGeneTF.regionTools import get_tss
from pybedtools.bedtool import BedTool
from SEGeneTF.sgt import tf_tss_rna, se_gene_tf

# %%
ann = read_annotation('./gal5_refseq.ucsc')
ann.head()
sig = read_chip_sigal_regions('./macs2.narrowPeaks.bed')
sig.head()
# Out:
#            name chrom strand   txStart     txEnd    name2
# 0  NM_001080101     1      +  33440187  33580652   SRGAP1
# 1     NM_205373     1      +   8310339   8452139   SEMA3D
# 2  NM_001079739     1      +  92260428  92282947     CD80
# 3  NM_001199314     1      +   1044880   1060889  ANKRD16
# 4  NM_001030773     1      -   3142580   3240472    MKLN1
#    chr   start     end            name
# 0    1   31626   31915  po.27ac_peak_1
# 1    1   32280   33741  po.27ac_peak_2
# 2    1   34204   34673  po.27ac_peak_3
# 3    1  486218  487724  po.27ac_peak_4
# 4    1  489390  490171  po.27ac_peak_5

# %%
se_gene_tf(
    '/home/yingh/data/20180716-GC-chip-seq/super-enh/po/po_AllEnhancers.table.txt', 
    '/home/yingh/bin/SEGeneTF/annotation/gal5_refseq.ucsc', 
    '/home/yingh/data/20180716-GC-chip-seq/macs2_27ac/po/po.27ac_peaks.narrowPeak.bed',
    tfs_input=['FOXL2'],
    genes_exp_path='/home/yingh/data/20180716-GC-chip-seq/crc_map/po_expNM_fpkm_lg1/po_crcmap_EXPRESSED_TRANSCRIPTS.txt',
    odir='./po_FOXL2_dnGenes',
    ifa_dir='/home/yingh/bin/SEGeneTF/splitChr/gal5',
    se_freq_thread=3,
)
# Out:
# <SE numbers:>  623
# /home/yingh/bin/SEGeneTF/sgt.py:128: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   index=False, header=None)
# <Candidate TFs:>  {'FOXL2'}
#            name chrom strand   txStart     txEnd    name2
# 0  NM_001080101     1      +  33440187  33580652   SRGAP1
# 2  NM_001079739     1      +  92260428  92282947     CD80
# 3  NM_001199314     1      +   1044880   1060889  ANKRD16
# 4  NM_001030773     1      -   3142580   3240472    MKLN1
# 5  NM_001199445     1      -  14570253  14754203     COG5
#   CHROM      START       STOP                          REGION_ID
# 0    11     578343     578343  51_po.27ac_peak_3412_lociStitched
# 1     1   31024954   31024954   47_po.27ac_peak_360_lociStitched
# 2     1  185072945  185072945  38_po.27ac_peak_2663_lociStitched
# ...

# %%
tss_res = tf_tss_rna(
    '/home/yingh/bin/SEGeneTF/annotation/gal5_refseq.ucsc', 
    '/home/yingh/data/20180716-GC-chip-seq/macs2_27ac/po/po.27ac_peaks.narrowPeak.bed',
    tfs_input=['FOXL2'],
    genes_exp_path='/home/yingh/data/20180716-GC-chip-seq/crc_map/po_exp.fpkm_lg1.csv',
    odir='./po_tss_FOXL2_dnGenes',
    ifa_dir='/home/yingh/bin/SEGeneTF/splitChr/gal5',
    tss_freq_thread=3,
    count_id_types='gn',
)
# Out:
# /home/yingh/bin/SEGeneTF/sgt.py:55: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   index=False, header=None)
# <Candidate TFs:>  {'FOXL2'}
# /home/yingh/anaconda3/envs/self_base/lib/python3.7/site-packages/pybedtools/bedtool.py:3439: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   return pandas.read_table(self.fn, *args, **kwargs)
# <Tx_symbol_ids_Lst>:
# <Get seq of peaks in TSS 2500.0-2500.0 ...>
# Reading FASTA file from '/home/yingh/bin/SEGeneTF/splitChr/gal5/7.fa.gz'...
# Reading FASTA file from '/home/yingh/bin/SEGeneTF/splitChr/gal5/18.fa.gz'...
# Reading FASTA file from '/home/yingh/bin/SEGeneTF/splitChr/gal5/28.fa.gz'...
# Reading FASTA file from '/home/yingh/bin/SEGeneTF/splitChr/gal5/26.fa.gz'...
# ...
